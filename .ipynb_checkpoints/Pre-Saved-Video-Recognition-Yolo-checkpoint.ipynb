# %%
# Import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Streaming webcam videos
webcam_video_stream = cv2.VideoCapture('images/video_sample.mp4')

while True:
    ret,current_frame = webcam_video_stream.read()
    img_to_detect = current_frame
    # get height and width of image
    img_height = img_to_detect.shape[0]
    img_width = img_to_detect.shape[1]
    # convert to blob to pass into model
    # recommended scale factor is 0.003922 = 1/255 and width, height of blob is 320,320
    # accepted sizes are 320*320 416*416, 609*609. More size means more accuracy but less spead
    img_blob = cv2.dnn.blobFromImage(img_to_detect,0.003922,(416,416),swapRB=True, crop=False)

    # Set of 80 class labels in alphabetical order (background + rest of 20 classes)
    class_labels = ["person","bicycle","car","motorcycle","airplane","bus","train","truck","boat","trafficlight","firehydrant",
                    "stopsign","parkingmeter","bench","bird","cat","dog","horse","sheep","cow","elephant","bear","zebra",
                    "giraffe","backpack","umbrella","handbag","tie","suitcase","frisbee","skis","snowboard","sportsball",
                    "kite","baseballbat","baseballglove","skateboard","surfboard","tennisracket","bottle","wineglass","cup",
                    "fork","knife","spoon","bowl","banana","apple","sandwich","orange","broccoli","carrot","hotdog","pizza",
                    "donut","cake","chair","sofa","pottedplant","bed","diningtable","toilet","tvmonitor","laptop","mouse",
                    "remote","keyboard","cellphone","microwave","oven","toaster","sink","refrigerator","book","clock","vase",
                    "scissors","teddybear","hairdrier","toothbrush"]
    
    
    #Declare List of colors as an array
    #Green, Blue, Red, cyan, yellow, purple
    #Split based on ',' and for every split, change type to int
    #convert that to a numpy array to apply color mask to the image numpy array
    class_colors = ["0,255,0","0,0,255","255,0,0","255,255,0","0,255,255"]
    class_colors = [np.array(every_color.split(",")).astype("int") for every_color in class_colors]
    class_colors = np.array(class_colors)
    class_colors = np.tile(class_colors,(16,1))

    # Loading pre-trained model from prototext and caffemodel files 
    yolo_model = cv2.dnn.readNetFromDarknet('datasets/yolov3.cfg','datasets/yolov3.weights')

    # Get all layers from yolo network
    # Loop and find the last layer (output layer) of the yolo network
    yolo_layers =yolo_model.getLayerNames()
    yolo_output_layer = [yolo_layers[yolo_layer[0]-1] for yolo_layer in yolo_model.getUnconnectedOutLayers()]
    # Input preprocessed blob into model and pass through the model
    yolo_model.setInput(img_blob)
    # obtain the detection predictions by the model using forward() method
    obj_detection_layers = yolo_model.forward(yolo_output_layer)

    # to fix multiple box overlapping issue using non-maximum supression (NMS)
    ############## NMS Change 1 ###############
    # initialization for non-max suppression (NMS)
    # declare list for [class id], [box center, width & height[], [confidences]
    class_ids_list = []
    boxes_list = []
    confidences_list = []
    ############## NMS Change 1 END ###########

    # loop over each of the layer outputs
    for object_detection_layer in obj_detection_layers:
        # loop over the detections
        for object_detection in object_detection_layer:

            # obj_detections[1 to 4] => will have the bounding box co-ordinates
            # obj_detections[5] => will have scores for all objects within bounding box
            all_scores = object_detection[5:]
            predicted_class_id = np.argmax(all_scores)
            prediction_confidence = all_scores[predicted_class_id]

            # take only predictions with confidence more than 50%
            if prediction_confidence > 0.5:
                # get the predicted label
                predicted_class_label = class_labels[predicted_class_id]
                # obtain the bounding box co-ordinates for the actual image from resized image size
                bounding_box = object_detection[0:4] * np.array([img_width, img_height, img_width, img_height])
                (box_center_x_pt, box_center_y_pt, box_width, box_height) = bounding_box.astype("int")
                start_x_pt = int(box_center_x_pt - (box_width/2))
                start_y_pt = int(box_center_y_pt - (box_height/2))

                ############## NMS Change 2 ###############
                #save class id, start x, y, width & height, confidences in a list for nms processing
                #make sure to pass confidence as float and width and height as integers
                class_ids_list.append(predicted_class_id)
                confidences_list.append(float(prediction_confidence))
                boxes_list.append([start_x_pt, start_y_pt, int(box_width), int(box_height)])
                ############## NMS Change 2 END ###########

    ############## NMS Change 3 ###############
    # Applying the NMS will return only the selected max value ids while suppressing the non maximum (weak) overlapping bounding boxes      
    # Non-Maxima Suppression confidence set as 0.5 & max_suppression threhold for NMS as 0.4 (adjust and try for better perfomance)
    max_value_ids = cv2.dnn.NMSBoxes(boxes_list, confidences_list, 0.5, 0.4)

    # loop through the final set of detections remaining after NMS and draw bounding box and write text
    for max_valueid in max_value_ids:
        max_class_id = max_valueid[0]
        box = boxes_list[max_class_id]
        start_x_pt = box[0]
        start_y_pt = box[1]
        box_width = box[2]
        box_height = box[3]

        #get the predicted class id and label
        predicted_class_id = class_ids_list[max_class_id]
        predicted_class_label = class_labels[predicted_class_id]
        prediction_confidence = confidences_list[max_class_id]
    ############## NMS Change 3 END ###########

        #obtain the bounding box end co-oridnates
        end_x_pt = start_x_pt + box_width
        end_y_pt = start_y_pt + box_height
        
        #get a random mask color from the numpy array of colors
        box_color = class_colors[predicted_class_id]
        
        #convert the color numpy array as a list and apply to text and box
        box_color = [int(c) for c in box_color]

        # Print the prediction in console
        predicted_class_label = "{}: {:.2f}%".format(class_labels[predicted_class_id],prediction_confidence*100)
        print("predicted object {}".format(predicted_class_label))

        # Draw rectangle and text in the image
        cv2.rectangle(img_to_detect, (start_x_pt,start_y_pt), (end_x_pt,end_y_pt), box_color,2)
        cv2.putText(img_to_detect, predicted_class_label, (start_x_pt,start_y_pt-5), cv2.FONT_HERSHEY_COMPLEX, 0.5, box_color,1)
    
    cv2.imshow("Detection Output", img_to_detect)

    # terminate while loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# releasing the stream and camera
webcam_video_stream.release()

# close all opencv windows
cv2.destroyAllWindows()
# Out:
# predicted object person: 98.51%
# predicted object person: 98.11%
# predicted object car: 97.10%
# predicted object car: 96.56%
# predicted object person: 96.14%
# predicted object car: 93.36%
# predicted object person: 93.17%
# predicted object car: 91.64%
# predicted object car: 85.13%
# predicted object truck: 84.26%
# predicted object person: 83.35%
# predicted object trafficlight: 81.29%
# predicted object truck: 79.48%
# predicted object person: 74.93%
# predicted object person: 73.36%
# predicted object person: 70.86%
# predicted object person: 69.52%
# predicted object truck: 66.78%
# predicted object car: 63.64%
# predicted object car: 62.47%
# predicted object car: 62.33%
# predicted object car: 59.97%
# predicted object person: 59.26%
# predicted object car: 56.76%
# predicted object person: 54.18%
# predicted object car: 52.85%
# predicted object trafficlight: 50.12%
# predicted object person: 50.04%
# predicted object person: 98.25%
# predicted object person: 97.90%
# predicted object car: 96.91%
# predicted object person: 95.74%
# predicted object car: 95.53%
# predicted object car: 94.81%
# predicted object person: 92.80%
# predicted object car: 90.84%
# predicted object person: 89.17%
# predicted object person: 86.11%
# predicted object truck: 82.10%
# predicted object car: 81.01%
# predicted object person: 79.75%
# predicted object trafficlight: 77.89%
# predicted object person: 76.97%
# predicted object truck: 74.41%
# predicted object person: 72.58%
# predicted object car: 71.56%
# predicted object car: 64.21%
# predicted object car: 63.70%
# predicted object person: 62.20%
# predicted object person: 58.39%
# predicted object car: 54.52%
# predicted object person: 53.59%
# predicted object car: 53.41%
# predicted object car: 50.52%
# predicted object trafficlight: 50.43%
# predicted object person: 97.88%
# predicted object person: 97.70%
# predicted object car: 97.39%
# predicted object car: 97.30%
# predicted object car: 94.82%
# predicted object person: 94.77%
# predicted object person: 94.49%
# predicted object person: 92.50%
# predicted object car: 90.64%
# predicted object truck: 88.50%
# predicted object person: 79.86%
# predicted object person: 79.80%
# predicted object person: 77.32%
# predicted object person: 76.95%
# predicted object car: 76.87%
# predicted object car: 75.52%
# predicted object trafficlight: 75.19%
# predicted object truck: 71.91%
# predicted object truck: 68.33%
# predicted object car: 66.95%
# predicted object car: 64.65%
# predicted object person: 64.02%
# predicted object person: 58.58%
# predicted object person: 57.89%
# predicted object car: 57.57%
# predicted object car: 56.55%
# predicted object car: 52.12%
# predicted object person: 98.99%
# predicted object person: 97.65%
# predicted object car: 97.14%
# predicted object car: 95.69%
# predicted object car: 95.02%
# predicted object person: 94.83%
# predicted object person: 94.19%
# predicted object person: 94.19%
# predicted object car: 90.86%
# predicted object truck: 86.97%
# predicted object person: 83.74%
# predicted object person: 80.01%
# predicted object car: 76.82%
# predicted object person: 74.95%
# predicted object trafficlight: 74.57%
# predicted object truck: 74.45%
# predicted object car: 71.11%
# predicted object person: 70.81%
# predicted object car: 66.66%
# predicted object person: 64.33%
# predicted object car: 61.64%
# predicted object person: 59.96%
# predicted object person: 57.88%
# predicted object person: 56.41%
# predicted object car: 55.72%
# predicted object car: 53.15%
# predicted object car: 50.45%
# predicted object person: 98.97%
# predicted object person: 97.70%
# predicted object car: 96.98%
# predicted object car: 95.82%
# predicted object person: 94.97%
# predicted object car: 94.95%
# predicted object person: 94.42%
# predicted object person: 94.21%
# predicted object car: 91.03%
# predicted object truck: 87.28%
# predicted object person: 83.84%
# predicted object person: 80.56%
# predicted object car: 77.88%
# predicted object truck: 75.07%
# predicted object trafficlight: 74.81%
# predicted object person: 74.55%
# predicted object car: 71.70%
# predicted object person: 70.44%
# predicted object car: 66.20%
# predicted object person: 65.58%
# predicted object car: 64.17%
# predicted object person: 61.16%
# predicted object person: 58.14%
# predicted object person: 57.61%
# predicted object car: 55.41%
# predicted object car: 54.26%
# predicted object car: 51.68%
# predicted object person: 98.61%
# predicted object person: 98.22%
# predicted object car: 97.11%
# predicted object car: 96.30%
# predicted object person: 95.55%
# predicted object car: 95.08%
# predicted object person: 93.98%
# predicted object person: 93.83%
# predicted object car: 91.07%
# predicted object truck: 88.48%
# predicted object person: 83.89%
# predicted object person: 78.65%
# predicted object person: 78.64%
# predicted object person: 74.88%
# predicted object truck: 73.74%
# predicted object truck: 73.35%
# predicted object car: 73.14%
# predicted object trafficlight: 72.55%
# predicted object car: 66.32%
# predicted object person: 65.29%
# predicted object car: 64.84%
# predicted object person: 63.36%
# predicted object car: 59.62%
# predicted object person: 59.12%
# predicted object person: 55.01%
# predicted object car: 52.12%
# predicted object person: 98.59%
# predicted object person: 98.45%
# predicted object car: 97.00%
# predicted object car: 96.72%
# predicted object person: 95.19%
# predicted object car: 94.80%
# predicted object person: 94.05%
# predicted object person: 93.61%
# predicted object car: 89.69%
# predicted object truck: 87.80%
# predicted object person: 84.46%
# predicted object person: 78.09%
# predicted object person: 76.46%
# predicted object car: 74.68%
# predicted object person: 73.49%
# predicted object truck: 72.89%
# predicted object car: 72.25%
# predicted object trafficlight: 71.77%
# predicted object person: 70.20%
# predicted object person: 67.85%
# predicted object car: 64.34%
# predicted object car: 55.09%
# predicted object person: 54.35%
# predicted object person: 51.36%
# predicted object person: 50.37%
# predicted object person: 99.07%
# predicted object person: 98.73%
# predicted object car: 98.23%
# predicted object car: 97.23%
# predicted object person: 95.77%
# predicted object person: 94.21%
# predicted object car: 93.80%
# predicted object car: 89.40%
# predicted object person: 89.00%
# predicted object truck: 87.26%
# predicted object person: 86.46%
# predicted object person: 82.71%
# predicted object person: 82.39%
# predicted object car: 75.00%
# predicted object truck: 71.69%
# predicted object trafficlight: 71.61%
# predicted object car: 71.57%
# predicted object person: 66.87%
# predicted object car: 65.72%
# predicted object person: 65.42%
# predicted object car: 63.03%
# predicted object car: 62.21%
# predicted object car: 60.21%
# predicted object person: 60.04%
# predicted object person: 55.38%
# predicted object person: 53.84%
# predicted object person: 98.75%
# predicted object person: 98.43%
# predicted object car: 97.90%
# predicted object car: 97.08%
# predicted object person: 95.77%
# predicted object car: 94.64%
# predicted object person: 93.73%
# predicted object person: 93.22%
# predicted object car: 88.92%
# predicted object truck: 88.37%
# predicted object person: 88.23%
# predicted object person: 86.73%
# predicted object person: 84.76%
# predicted object person: 80.61%
# predicted object car: 76.70%
# predicted object truck: 75.78%
# predicted object person: 74.66%
# predicted object trafficlight: 74.42%
# predicted object person: 73.13%
# predicted object car: 72.60%
# predicted object car: 69.29%
# predicted object car: 62.30%
# predicted object person: 61.87%
# predicted object car: 59.42%
# predicted object person: 58.15%
# predicted object car: 51.49%
# predicted object person: 98.65%
# predicted object person: 98.43%
# predicted object car: 97.24%
# predicted object car: 97.11%
# predicted object person: 97.07%
# predicted object person: 94.72%
# predicted object car: 93.93%
# predicted object person: 92.05%
# predicted object person: 91.12%
# predicted object car: 90.07%
# predicted object car: 88.91%
# predicted object person: 88.73%
# predicted object truck: 87.65%
# predicted object person: 87.65%
# predicted object person: 86.83%
# predicted object person: 77.71%
# predicted object person: 77.06%
# predicted object truck: 75.57%
# predicted object person: 75.20%
# predicted object trafficlight: 73.60%
# predicted object car: 68.59%
# predicted object car: 65.78%
# predicted object car: 63.34%
# predicted object person: 54.58%
# predicted object car: 54.32%
# predicted object car: 50.91%
# predicted object person: 98.67%
# predicted object person: 98.49%
# predicted object car: 97.38%
# predicted object person: 97.11%
# predicted object car: 97.10%
# predicted object person: 94.71%
# predicted object car: 94.01%
# predicted object person: 92.08%
# predicted object person: 91.03%
# predicted object car: 89.62%
# predicted object person: 88.99%
# predicted object car: 88.46%
# predicted object truck: 88.21%
# predicted object person: 86.74%
# predicted object person: 86.66%
# predicted object person: 80.08%
# predicted object person: 76.66%
# predicted object person: 76.37%
# predicted object truck: 76.14%
# predicted object trafficlight: 73.31%
# predicted object car: 70.32%
# predicted object car: 67.22%
# predicted object car: 65.99%
# predicted object person: 55.00%
# predicted object car: 54.59%
# predicted object car: 54.19%
# predicted object car: 98.18%
# predicted object person: 97.96%
# predicted object person: 97.78%
# predicted object car: 96.97%
# predicted object person: 96.92%
# predicted object person: 94.82%
# predicted object person: 93.35%
# predicted object car: 90.02%
# predicted object person: 89.22%
# predicted object car: 88.95%
# predicted object truck: 88.53%
# predicted object car: 88.49%
# predicted object person: 85.82%
# predicted object person: 85.42%
# predicted object person: 84.48%
# predicted object person: 82.23%
# predicted object truck: 79.56%
# predicted object person: 78.86%
# predicted object person: 76.98%
# predicted object trafficlight: 70.06%
# predicted object car: 69.86%
# predicted object car: 69.53%
# predicted object car: 67.94%
# predicted object car: 63.78%
# predicted object car: 59.74%
# predicted object person: 57.22%
# predicted object car: 97.49%
# predicted object person: 97.30%
# predicted object person: 96.78%
# predicted object car: 96.56%
# predicted object person: 96.39%
# predicted object person: 94.39%
# predicted object person: 93.31%
# predicted object person: 92.95%
# predicted object car: 91.61%
# predicted object car: 89.60%
# predicted object truck: 89.58%
# predicted object car: 88.48%
# predicted object person: 86.62%
# predicted object person: 85.33%
# predicted object truck: 82.79%
# predicted object person: 81.20%
# predicted object person: 80.36%
# predicted object person: 79.53%
# predicted object person: 78.63%
# predicted object car: 71.51%
# predicted object car: 68.72%
# predicted object car: 68.57%
# predicted object trafficlight: 68.32%
# predicted object car: 67.47%
# predicted object car: 64.68%
# predicted object person: 62.04%
# predicted object person: 53.86%
# predicted object person: 98.29%
# predicted object person: 96.83%
# predicted object car: 96.58%
# predicted object person: 96.03%
# predicted object car: 95.44%
# predicted object person: 93.64%
# predicted object person: 92.28%
# predicted object person: 91.98%
# predicted object car: 89.70%
# predicted object truck: 88.66%
# predicted object person: 87.86%
# predicted object car: 86.12%
# predicted object person: 85.22%
# predicted object truck: 82.47%
# predicted object car: 82.43%
# predicted object person: 78.50%
# predicted object person: 75.68%
# predicted object person: 74.82%
# predicted object car: 72.21%
# predicted object car: 69.07%
# predicted object trafficlight: 68.48%
# predicted object car: 67.84%
# predicted object car: 63.67%
# predicted object car: 59.79%
# predicted object person: 59.16%
# predicted object person: 99.06%
# predicted object person: 97.46%
# predicted object person: 97.30%
# predicted object car: 96.63%
# predicted object car: 95.34%
# predicted object person: 93.88%
# predicted object car: 92.33%
# predicted object person: 91.15%
# predicted object person: 89.96%
# predicted object car: 89.24%
# predicted object person: 88.06%
# predicted object truck: 85.51%
# predicted object person: 84.80%
# predicted object person: 84.58%
# predicted object car: 82.85%
# predicted object truck: 79.80%
# predicted object person: 78.32%
# predicted object car: 72.69%
# predicted object car: 69.65%
# predicted object trafficlight: 69.32%
# predicted object person: 69.18%
# predicted object car: 68.64%
# predicted object car: 68.00%
# predicted object person: 62.77%
# predicted object person: 62.32%
# predicted object car: 62.28%
# predicted object person: 99.27%
# predicted object person: 98.73%
# predicted object car: 96.75%
# predicted object person: 95.53%
# predicted object car: 94.92%
# predicted object person: 92.79%
# predicted object person: 91.74%
# predicted object car: 90.61%
# predicted object person: 89.56%
# predicted object person: 88.25%
# predicted object car: 87.81%
# predicted object truck: 84.36%
# predicted object person: 81.09%
# predicted object person: 79.66%
# predicted object car: 77.49%
# predicted object person: 77.07%
# predicted object truck: 76.02%
# predicted object car: 70.98%
# predicted object car: 68.12%
# predicted object trafficlight: 67.96%
# predicted object car: 67.27%
# predicted object person: 62.78%
# predicted object car: 61.43%
# predicted object truck: 60.52%
# predicted object person: 59.89%
# predicted object person: 58.07%
# predicted object person: 53.07%
# predicted object person: 99.26%
# predicted object person: 98.74%
# predicted object car: 96.59%
# predicted object car: 95.00%
# predicted object person: 94.97%
# predicted object person: 93.10%
# predicted object person: 91.98%
# predicted object person: 89.71%
# predicted object car: 88.17%
# predicted object person: 88.07%
# predicted object car: 86.28%
# predicted object truck: 84.57%
# predicted object person: 81.76%
# predicted object person: 80.09%
# predicted object person: 76.09%
# predicted object truck: 76.09%
# predicted object car: 75.07%
# predicted object car: 69.24%
# predicted object car: 68.95%
# predicted object trafficlight: 68.67%
# predicted object car: 67.90%
# predicted object truck: 66.09%
# predicted object car: 65.69%
# predicted object person: 63.49%
# predicted object person: 60.48%
# predicted object person: 56.82%
# predicted object person: 53.40%
# predicted object person: 99.17%
# predicted object person: 99.14%
# predicted object car: 96.56%
# predicted object person: 94.87%
# predicted object person: 93.40%
# predicted object car: 93.38%
# predicted object person: 91.75%
# predicted object person: 89.66%
# predicted object person: 88.94%
# predicted object car: 86.42%
# predicted object truck: 82.87%
# predicted object truck: 81.43%
# predicted object person: 80.61%
# predicted object person: 77.35%
# predicted object car: 76.75%
# predicted object person: 74.93%
# predicted object car: 71.30%
# predicted object car: 70.09%
# predicted object trafficlight: 69.81%
# predicted object car: 69.39%
# predicted object person: 68.08%
# predicted object car: 64.80%
# predicted object car: 62.61%
# predicted object person: 59.23%
# predicted object truck: 58.24%
# predicted object person: 57.27%
# predicted object car: 51.29%
# predicted object person: 99.13%
# predicted object person: 98.89%
# predicted object car: 96.69%
# predicted object person: 95.48%
# predicted object person: 92.12%
# predicted object person: 91.04%
# predicted object car: 90.89%
# predicted object person: 89.53%
# predicted object person: 88.71%
# predicted object car: 84.76%
# predicted object truck: 84.68%
# predicted object truck: 77.94%
# predicted object person: 77.71%
# predicted object car: 77.38%
# predicted object person: 76.37%
# predicted object car: 75.79%
# predicted object person: 71.96%
# predicted object trafficlight: 71.48%
# predicted object person: 71.40%
# predicted object car: 70.67%
# predicted object car: 68.59%
# predicted object person: 65.16%
# predicted object person: 64.86%
# predicted object person: 62.65%
# predicted object car: 54.91%
# predicted object car: 54.89%
# predicted object car: 52.69%
# predicted object car: 52.52%
# predicted object trafficlight: 52.40%
# predicted object person: 99.22%
# predicted object person: 99.02%
# predicted object person: 97.06%
# predicted object car: 97.05%
# predicted object person: 95.08%
# predicted object car: 91.46%
# predicted object person: 89.92%
# predicted object person: 88.40%
# predicted object car: 88.27%
# predicted object person: 87.96%
# predicted object truck: 86.35%
# predicted object car: 84.52%
# predicted object person: 81.07%
# predicted object car: 78.79%
# predicted object person: 75.94%
# predicted object person: 73.97%
# predicted object trafficlight: 72.67%
# predicted object car: 71.29%
# predicted object truck: 70.50%
# predicted object car: 70.07%
# predicted object person: 67.10%
# predicted object person: 64.00%
# predicted object person: 63.01%
# predicted object truck: 61.69%
# predicted object person: 59.86%
# predicted object car: 57.64%
# predicted object car: 54.42%
# predicted object trafficlight: 54.20%
# predicted object person: 99.16%
# predicted object person: 98.77%
# predicted object car: 96.94%
# predicted object person: 95.80%
# predicted object person: 95.44%
# predicted object car: 92.33%
# predicted object person: 90.84%
# predicted object person: 89.26%
# predicted object car: 87.59%
# predicted object person: 85.38%
# predicted object car: 84.99%
# predicted object truck: 84.09%
# predicted object person: 84.00%
# predicted object person: 79.36%
# predicted object car: 76.43%
# predicted object car: 75.52%
# predicted object person: 71.68%
# predicted object car: 71.49%
# predicted object car: 70.19%
# predicted object person: 69.73%
# predicted object trafficlight: 69.07%
# predicted object person: 64.57%
# predicted object car: 64.50%
# predicted object car: 58.96%
# predicted object car: 57.04%
# predicted object car: 56.81%
# predicted object person: 51.55%
# predicted object person: 99.00%
# predicted object person: 98.14%
# predicted object car: 97.01%
# predicted object person: 96.86%
# predicted object person: 95.54%
# predicted object car: 93.97%
# predicted object car: 92.34%
# predicted object person: 91.24%
# predicted object person: 89.05%
# predicted object person: 86.42%
# predicted object person: 86.09%
# predicted object truck: 85.99%
# predicted object car: 84.55%
# predicted object person: 81.40%
# predicted object car: 79.09%
# predicted object car: 76.32%
# predicted object car: 72.97%
# predicted object car: 69.60%
# predicted object trafficlight: 69.26%
# predicted object person: 68.91%
# predicted object truck: 68.05%
# predicted object person: 66.31%
# predicted object person: 64.25%
# predicted object car: 61.54%
# predicted object car: 59.32%
# predicted object person: 56.67%
# predicted object person: 55.15%
# predicted object trafficlight: 51.94%
# predicted object truck: 51.80%
# predicted object person: 98.93%
# predicted object person: 98.09%
# predicted object car: 96.99%
# predicted object person: 96.85%
# predicted object person: 95.45%
# predicted object car: 93.94%
# predicted object car: 91.91%
# predicted object person: 91.14%
# predicted object person: 89.47%
# predicted object person: 86.72%
# predicted object person: 86.45%
# predicted object truck: 85.57%
# predicted object car: 84.29%
# predicted object person: 81.10%
# predicted object car: 78.37%
# predicted object car: 76.16%
# predicted object car: 72.78%
# predicted object person: 69.51%
# predicted object trafficlight: 69.03%
# predicted object car: 68.57%
# predicted object truck: 68.06%
# predicted object person: 67.49%
# predicted object person: 63.15%
# predicted object car: 59.41%
# predicted object car: 57.54%
# predicted object person: 56.78%
# predicted object trafficlight: 52.61%
# predicted object person: 98.93%
# predicted object person: 98.09%
# predicted object car: 96.99%
# predicted object person: 96.87%
# predicted object person: 95.45%
# predicted object car: 93.93%
# predicted object car: 91.82%
# predicted object person: 91.06%
# predicted object person: 89.48%
# predicted object person: 86.72%
# predicted object person: 86.45%
# predicted object truck: 85.58%
# predicted object car: 84.28%
# predicted object person: 81.08%
# predicted object car: 78.34%
# predicted object car: 76.16%
# predicted object car: 72.83%
# predicted object person: 69.52%
# predicted object trafficlight: 69.01%
# predicted object car: 68.54%
# predicted object truck: 67.92%
# predicted object person: 67.51%
# predicted object person: 63.13%
# predicted object car: 59.38%
# predicted object car: 57.58%
# predicted object person: 56.78%
# predicted object trafficlight: 52.62%
# predicted object person: 98.37%
# predicted object person: 97.94%
# predicted object person: 97.33%
# predicted object car: 97.14%
# predicted object person: 94.86%
# predicted object person: 92.97%
# predicted object car: 91.26%
# predicted object person: 90.12%
# predicted object person: 87.10%
# predicted object car: 86.83%
# predicted object truck: 86.37%
# predicted object person: 84.50%
# predicted object car: 83.26%
# predicted object car: 79.90%
# predicted object car: 76.06%
# predicted object car: 75.94%
# predicted object person: 75.60%
# predicted object car: 75.60%
# predicted object truck: 72.56%
# predicted object trafficlight: 69.31%
# predicted object person: 68.75%
# predicted object person: 65.64%
# predicted object car: 64.59%
# predicted object person: 63.80%
# predicted object person: 57.14%
# predicted object trafficlight: 52.33%
# predicted object person: 97.85%
# predicted object person: 97.10%
# predicted object person: 96.97%
# predicted object car: 96.88%
# predicted object person: 95.59%
# predicted object person: 93.82%
# predicted object car: 91.35%
# predicted object car: 89.37%
# predicted object person: 88.27%
# predicted object person: 88.00%
# predicted object truck: 86.72%
# predicted object person: 85.70%
# predicted object car: 82.32%
# predicted object person: 79.20%
# predicted object car: 77.63%
# predicted object car: 76.68%
# predicted object car: 74.43%
# predicted object car: 73.24%
# predicted object truck: 73.07%
# predicted object trafficlight: 69.53%
# predicted object person: 65.28%
# predicted object person: 64.03%
# predicted object person: 63.11%
# predicted object car: 62.78%
# predicted object person: 53.44%
# predicted object trafficlight: 52.67%
# predicted object person: 97.94%
# predicted object person: 97.27%
# predicted object car: 96.59%
# predicted object person: 95.84%
# predicted object person: 94.88%
# predicted object person: 93.95%
# predicted object car: 90.34%
# predicted object car: 89.06%
# predicted object person: 88.95%
# predicted object person: 88.93%
# predicted object truck: 88.40%
# predicted object person: 87.11%
# predicted object person: 83.71%
# predicted object person: 82.91%
# predicted object car: 79.88%
# predicted object car: 78.82%
# predicted object car: 77.40%
# predicted object car: 77.04%
# predicted object car: 74.32%
# predicted object trafficlight: 73.93%
# predicted object truck: 73.65%
# predicted object person: 67.91%
# predicted object person: 65.45%
# predicted object person: 64.21%
# predicted object car: 63.07%
# predicted object person: 98.04%
# predicted object person: 97.02%
# predicted object person: 96.93%
# predicted object car: 96.03%
# predicted object person: 95.76%
# predicted object person: 95.02%
# predicted object person: 91.02%
# predicted object car: 90.51%
# predicted object person: 89.96%
# predicted object car: 89.01%
# predicted object person: 88.37%
# predicted object truck: 87.90%
# predicted object person: 87.31%
# predicted object person: 85.51%
# predicted object person: 84.77%
# predicted object car: 77.89%
# predicted object car: 77.62%
# predicted object car: 77.59%
# predicted object car: 75.19%
# predicted object car: 73.63%
# predicted object trafficlight: 72.15%
# predicted object truck: 68.18%
# predicted object person: 67.05%
# predicted object person: 66.93%
# predicted object car: 60.60%
# predicted object person: 57.85%
# predicted object person: 52.77%
# predicted object trafficlight: 50.13%
# predicted object person: 98.32%
# predicted object person: 98.31%
# predicted object person: 96.36%
# predicted object car: 96.03%
# predicted object person: 95.82%
# predicted object person: 94.72%
# predicted object car: 92.75%
# predicted object person: 92.59%
# predicted object person: 91.76%
# predicted object car: 90.06%
# predicted object person: 89.35%
# predicted object truck: 88.40%
# predicted object person: 87.10%
# predicted object person: 86.97%
# predicted object car: 80.78%
# predicted object car: 77.01%
# predicted object person: 76.72%
# predicted object car: 76.55%
# predicted object car: 76.07%
# predicted object trafficlight: 72.77%
# predicted object person: 70.56%
# predicted object car: 68.50%
# predicted object person: 67.34%
# predicted object car: 64.08%
# predicted object truck: 63.10%
# predicted object person: 50.67%
# predicted object person: 50.49%
# predicted object trafficlight: 50.39%
# predicted object person: 98.40%
# predicted object person: 98.30%
# predicted object person: 96.24%
# predicted object car: 96.08%
# predicted object person: 95.73%
# predicted object person: 94.74%
# predicted object car: 93.00%
# predicted object person: 92.24%
# predicted object person: 90.98%
# predicted object car: 90.16%
# predicted object person: 89.16%
# predicted object truck: 88.30%
# predicted object person: 87.04%
# predicted object person: 86.46%
# predicted object car: 80.45%
# predicted object person: 79.02%
# predicted object car: 76.55%
# predicted object car: 75.91%
# predicted object car: 72.95%
# predicted object trafficlight: 72.83%
# predicted object person: 69.93%
# predicted object car: 67.20%
# predicted object person: 66.88%
# predicted object car: 63.92%
# predicted object car: 62.50%
# predicted object trafficlight: 54.64%
# predicted object person: 51.52%
# predicted object person: 98.50%
# predicted object person: 98.35%
# predicted object person: 96.12%
# predicted object car: 95.98%
# predicted object person: 95.02%
# predicted object person: 93.66%
# predicted object person: 90.54%
# predicted object car: 90.29%
# predicted object person: 88.91%
# predicted object truck: 88.26%
# predicted object person: 87.27%
# predicted object person: 86.45%
# predicted object person: 86.17%
# predicted object car: 78.94%
# predicted object car: 76.49%
# predicted object car: 73.37%
# predicted object car: 73.05%
# predicted object car: 72.38%
# predicted object trafficlight: 71.97%
# predicted object person: 70.41%
# predicted object car: 69.04%
# predicted object car: 66.77%
# predicted object person: 61.58%
# predicted object person: 61.04%
# predicted object car: 60.25%
# predicted object person: 59.70%
# predicted object trafficlight: 52.65%
# predicted object person: 98.76%
# predicted object person: 98.28%
# predicted object person: 97.57%
# predicted object car: 96.09%
# predicted object person: 95.32%
# predicted object person: 93.65%
# predicted object person: 91.28%
# predicted object person: 91.17%
# predicted object car: 88.74%
# predicted object truck: 88.50%
# predicted object person: 87.02%
# predicted object person: 86.33%
# predicted object car: 82.33%
# predicted object person: 81.81%
# predicted object car: 77.90%
# predicted object car: 76.09%
# predicted object car: 76.08%
# predicted object trafficlight: 72.23%
# predicted object car: 71.93%
# predicted object person: 70.36%
# predicted object car: 68.75%
# predicted object person: 68.17%
# predicted object car: 67.36%
# predicted object person: 66.18%
# predicted object car: 59.36%
# predicted object person: 59.23%
# predicted object trafficlight: 55.02%
# predicted object person: 98.68%
# predicted object person: 98.17%
# predicted object person: 97.62%
# predicted object car: 96.12%
# predicted object person: 95.80%
# predicted object person: 92.57%
# predicted object person: 92.11%
# predicted object person: 89.45%
# predicted object truck: 88.37%
# predicted object person: 87.25%
# predicted object car: 86.44%
# predicted object person: 83.45%
# predicted object car: 81.99%
# predicted object car: 81.46%
# predicted object person: 80.77%
# predicted object car: 77.24%
# predicted object car: 77.05%
# predicted object trafficlight: 74.90%
# predicted object car: 70.80%
# predicted object person: 68.71%
# predicted object person: 67.48%
# predicted object person: 67.20%
# predicted object car: 62.93%
# predicted object trafficlight: 56.88%
# predicted object car: 56.35%
# predicted object person: 53.51%
# predicted object person: 98.19%
# predicted object person: 98.12%
# predicted object person: 97.11%
# predicted object car: 95.90%
# predicted object person: 95.78%
# predicted object person: 93.19%
# predicted object person: 91.59%
# predicted object person: 89.75%
# predicted object truck: 88.57%
# predicted object person: 86.78%
# predicted object car: 86.45%
# predicted object car: 84.89%
# predicted object person: 83.98%
# predicted object person: 83.18%
# predicted object car: 80.31%
# predicted object trafficlight: 74.36%
# predicted object car: 72.93%
# predicted object car: 72.89%
# predicted object car: 69.78%
# predicted object person: 67.02%
# predicted object car: 66.12%
# predicted object person: 58.99%
# predicted object person: 57.51%
# predicted object car: 56.71%
# predicted object trafficlight: 53.57%
# predicted object car: 52.54%
# predicted object person: 98.46%
# predicted object person: 97.55%
# predicted object person: 97.25%
# predicted object car: 95.92%
# predicted object person: 95.23%
# predicted object person: 93.15%
# predicted object person: 92.61%
# predicted object person: 91.61%
# predicted object truck: 88.34%
# predicted object person: 88.20%
# predicted object car: 88.18%
# predicted object person: 87.73%
# predicted object person: 83.85%
# predicted object car: 83.73%
# predicted object car: 81.54%
# predicted object person: 77.93%
# predicted object car: 75.79%
# predicted object car: 73.73%
# predicted object trafficlight: 73.12%
# predicted object car: 70.52%
# predicted object person: 65.38%
# predicted object person: 65.19%
# predicted object car: 63.50%
# predicted object car: 60.62%
# predicted object person: 59.26%
# predicted object trafficlight: 54.75%
