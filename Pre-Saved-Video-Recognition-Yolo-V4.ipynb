# %%
# Import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Streaming webcam videos
webcam_video_stream = cv2.VideoCapture('images/video_sample.mp4')

while True:
    ret,current_frame = webcam_video_stream.read()
    img_to_detect = current_frame
    # get height and width of image
    img_height = img_to_detect.shape[0]
    img_width = img_to_detect.shape[1]
    # convert to blob to pass into model
    # recommended scale factor is 0.003922 = 1/255 and width, height of blob is 320,320
    # accepted sizes are 320*320 416*416, 609*609. More size means more accuracy but less spead
    img_blob = cv2.dnn.blobFromImage(img_to_detect,0.003922,(416,416),swapRB=True, crop=False)

    # Set of 80 class labels in alphabetical order (background + rest of 20 classes)
    class_labels = ["person","bicycle","car","motorcycle","airplane","bus","train","truck","boat","trafficlight","firehydrant",
                    "stopsign","parkingmeter","bench","bird","cat","dog","horse","sheep","cow","elephant","bear","zebra",
                    "giraffe","backpack","umbrella","handbag","tie","suitcase","frisbee","skis","snowboard","sportsball",
                    "kite","baseballbat","baseballglove","skateboard","surfboard","tennisracket","bottle","wineglass","cup",
                    "fork","knife","spoon","bowl","banana","apple","sandwich","orange","broccoli","carrot","hotdog","pizza",
                    "donut","cake","chair","sofa","pottedplant","bed","diningtable","toilet","tvmonitor","laptop","mouse",
                    "remote","keyboard","cellphone","microwave","oven","toaster","sink","refrigerator","book","clock","vase",
                    "scissors","teddybear","hairdrier","toothbrush"]
    
    
    #Declare List of colors as an array
    #Green, Blue, Red, cyan, yellow, purple
    #Split based on ',' and for every split, change type to int
    #convert that to a numpy array to apply color mask to the image numpy array
    class_colors = ["0,255,0","0,0,255","255,0,0","255,255,0","0,255,255"]
    class_colors = [np.array(every_color.split(",")).astype("int") for every_color in class_colors]
    class_colors = np.array(class_colors)
    class_colors = np.tile(class_colors,(16,1))

    # Loading pre-trained model from prototext and caffemodel files 
    yolo_model = cv2.dnn.readNetFromDarknet('datasets/yolov4.cfg','datasets/yolov4.weights')

    # Get all layers from yolo network
    # Loop and find the last layer (output layer) of the yolo network
    yolo_layers =yolo_model.getLayerNames()
    yolo_output_layer = [yolo_layers[yolo_layer[0]-1] for yolo_layer in yolo_model.getUnconnectedOutLayers()]
    # Input preprocessed blob into model and pass through the model
    yolo_model.setInput(img_blob)
    # obtain the detection predictions by the model using forward() method
    obj_detection_layers = yolo_model.forward(yolo_output_layer)

    # to fix multiple box overlapping issue using non-maximum supression (NMS)
    ############## NMS Change 1 ###############
    # initialization for non-max suppression (NMS)
    # declare list for [class id], [box center, width & height[], [confidences]
    class_ids_list = []
    boxes_list = []
    confidences_list = []
    ############## NMS Change 1 END ###########

    # loop over each of the layer outputs
    for object_detection_layer in obj_detection_layers:
        # loop over the detections
        for object_detection in object_detection_layer:

            # obj_detections[1 to 4] => will have the bounding box co-ordinates
            # obj_detections[5] => will have scores for all objects within bounding box
            all_scores = object_detection[5:]
            predicted_class_id = np.argmax(all_scores)
            prediction_confidence = all_scores[predicted_class_id]

            # take only predictions with confidence more than 50%
            if prediction_confidence > 0.5:
                # get the predicted label
                predicted_class_label = class_labels[predicted_class_id]
                # obtain the bounding box co-ordinates for the actual image from resized image size
                bounding_box = object_detection[0:4] * np.array([img_width, img_height, img_width, img_height])
                (box_center_x_pt, box_center_y_pt, box_width, box_height) = bounding_box.astype("int")
                start_x_pt = int(box_center_x_pt - (box_width/2))
                start_y_pt = int(box_center_y_pt - (box_height/2))

                ############## NMS Change 2 ###############
                #save class id, start x, y, width & height, confidences in a list for nms processing
                #make sure to pass confidence as float and width and height as integers
                class_ids_list.append(predicted_class_id)
                confidences_list.append(float(prediction_confidence))
                boxes_list.append([start_x_pt, start_y_pt, int(box_width), int(box_height)])
                ############## NMS Change 2 END ###########

    ############## NMS Change 3 ###############
    # Applying the NMS will return only the selected max value ids while suppressing the non maximum (weak) overlapping bounding boxes      
    # Non-Maxima Suppression confidence set as 0.5 & max_suppression threhold for NMS as 0.4 (adjust and try for better perfomance)
    max_value_ids = cv2.dnn.NMSBoxes(boxes_list, confidences_list, 0.5, 0.4)

    # loop through the final set of detections remaining after NMS and draw bounding box and write text
    for max_valueid in max_value_ids:
        max_class_id = max_valueid[0]
        box = boxes_list[max_class_id]
        start_x_pt = box[0]
        start_y_pt = box[1]
        box_width = box[2]
        box_height = box[3]

        #get the predicted class id and label
        predicted_class_id = class_ids_list[max_class_id]
        predicted_class_label = class_labels[predicted_class_id]
        prediction_confidence = confidences_list[max_class_id]
    ############## NMS Change 3 END ###########

        #obtain the bounding box end co-oridnates
        end_x_pt = start_x_pt + box_width
        end_y_pt = start_y_pt + box_height
        
        #get a random mask color from the numpy array of colors
        box_color = class_colors[predicted_class_id]
        
        #convert the color numpy array as a list and apply to text and box
        box_color = [int(c) for c in box_color]

        # Print the prediction in console
        predicted_class_label = "{}: {:.2f}%".format(class_labels[predicted_class_id],prediction_confidence*100)
        print("predicted object {}".format(predicted_class_label))

        # Draw rectangle and text in the image
        cv2.rectangle(img_to_detect, (start_x_pt,start_y_pt), (end_x_pt,end_y_pt), box_color,2)
        cv2.putText(img_to_detect, predicted_class_label, (start_x_pt,start_y_pt-5), cv2.FONT_HERSHEY_COMPLEX, 0.5, box_color,1)
    
    cv2.imshow("Detection Output", img_to_detect)

    # terminate while loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# releasing the stream and camera
webcam_video_stream.release()

# close all opencv windows
cv2.destroyAllWindows()
# Out:
# predicted object truck: 95.68%
# predicted object car: 94.38%
# predicted object car: 88.54%
# predicted object person: 88.13%
# predicted object person: 82.83%
# predicted object car: 82.32%
# predicted object person: 79.21%
# predicted object person: 79.11%
# predicted object car: 76.85%
# predicted object car: 75.60%
# predicted object truck: 74.43%
# predicted object person: 73.84%
# predicted object person: 67.39%
# predicted object truck: 66.21%
# predicted object person: 66.10%
# predicted object trafficlight: 60.68%
# predicted object trafficlight: 55.44%
# predicted object trafficlight: 51.55%
# predicted object person: 50.95%
# predicted object truck: 95.17%
# predicted object car: 93.44%
# predicted object car: 89.07%
# predicted object person: 88.42%
# predicted object truck: 87.62%
# predicted object person: 82.62%
# predicted object car: 80.91%
# predicted object person: 79.79%
# predicted object person: 78.69%
# predicted object car: 77.16%
# predicted object person: 73.12%
# predicted object car: 72.43%
# predicted object person: 68.40%
# predicted object person: 65.51%
# predicted object truck: 64.65%
# predicted object trafficlight: 55.88%
# predicted object trafficlight: 53.58%
# predicted object trafficlight: 50.74%
# predicted object person: 50.61%
# predicted object car: 50.28%
# predicted object truck: 96.30%
# predicted object car: 88.71%
# predicted object car: 88.56%
# predicted object person: 87.58%
# predicted object person: 86.45%
# predicted object car: 84.01%
# predicted object truck: 82.79%
# predicted object car: 78.36%
# predicted object person: 77.96%
# predicted object person: 76.61%
# predicted object person: 72.80%
# predicted object person: 72.34%
# predicted object car: 71.81%
# predicted object person: 62.97%
# predicted object truck: 61.27%
# predicted object trafficlight: 55.79%
# predicted object car: 53.19%
# predicted object trafficlight: 52.24%
# predicted object truck: 95.90%
# predicted object car: 92.90%
# predicted object person: 88.77%
# predicted object car: 88.58%
# predicted object person: 88.27%
# predicted object person: 84.94%
# predicted object car: 84.02%
# predicted object person: 81.31%
# predicted object car: 79.16%
# predicted object person: 74.23%
# predicted object person: 73.50%
# predicted object truck: 73.30%
# predicted object car: 71.66%
# predicted object person: 64.78%
# predicted object truck: 56.44%
# predicted object trafficlight: 56.14%
# predicted object trafficlight: 54.63%
# predicted object car: 50.49%
# predicted object truck: 96.06%
# predicted object car: 92.23%
# predicted object person: 89.07%
# predicted object person: 88.31%
# predicted object car: 87.98%
# predicted object person: 85.08%
# predicted object car: 84.01%
# predicted object person: 81.59%
# predicted object car: 79.56%
# predicted object truck: 75.68%
# predicted object person: 73.38%
# predicted object person: 73.21%
# predicted object car: 71.87%
# predicted object person: 64.79%
# predicted object truck: 58.08%
# predicted object trafficlight: 55.43%
# predicted object trafficlight: 52.44%
# predicted object car: 51.86%
# predicted object person: 50.66%
# predicted object truck: 96.25%
# predicted object car: 94.44%
# predicted object truck: 91.31%
# predicted object person: 90.84%
# predicted object person: 89.53%
# predicted object car: 84.72%
# predicted object car: 84.70%
# predicted object person: 84.04%
# predicted object car: 80.54%
# predicted object person: 79.91%
# predicted object person: 77.50%
# predicted object person: 75.68%
# predicted object car: 69.58%
# predicted object person: 64.75%
# predicted object truck: 56.16%
# predicted object car: 55.11%
# predicted object trafficlight: 53.65%
# predicted object person: 52.26%
# predicted object trafficlight: 50.83%
# predicted object person: 50.61%
# predicted object truck: 94.98%
# predicted object car: 92.54%
# predicted object person: 91.83%
# predicted object person: 88.39%
# predicted object person: 86.58%
# predicted object car: 85.86%
# predicted object car: 84.70%
# predicted object car: 80.64%
# predicted object truck: 79.25%
# predicted object person: 78.00%
# predicted object person: 77.77%
# predicted object person: 74.41%
# predicted object car: 72.07%
# predicted object person: 64.04%
# predicted object truck: 53.09%
# predicted object trafficlight: 52.66%
# predicted object person: 52.25%
# predicted object trafficlight: 51.69%
# predicted object person: 50.61%
# predicted object truck: 95.68%
# predicted object car: 92.39%
# predicted object person: 89.66%
# predicted object person: 88.25%
# predicted object person: 88.07%
# predicted object car: 82.34%
# predicted object car: 82.31%
# predicted object car: 81.62%
# predicted object truck: 79.37%
# predicted object person: 76.98%
# predicted object person: 76.84%
# predicted object person: 76.00%
# predicted object car: 68.33%
# predicted object person: 64.32%
# predicted object car: 59.74%
# predicted object truck: 53.45%
# predicted object trafficlight: 51.32%
# predicted object truck: 95.80%
# predicted object car: 91.84%
# predicted object person: 88.50%
# predicted object car: 87.35%
# predicted object person: 87.07%
# predicted object person: 87.06%
# predicted object car: 83.50%
# predicted object car: 83.23%
# predicted object car: 82.91%
# predicted object person: 77.73%
# predicted object person: 76.86%
# predicted object person: 75.90%
# predicted object car: 72.53%
# predicted object truck: 72.34%
# predicted object person: 65.58%
# predicted object trafficlight: 54.76%
# predicted object truck: 53.73%
# predicted object person: 50.91%
# predicted object truck: 96.35%
# predicted object car: 91.66%
# predicted object person: 87.35%
# predicted object person: 87.20%
# predicted object car: 86.01%
# predicted object person: 85.08%
# predicted object car: 83.43%
# predicted object person: 79.13%
# predicted object car: 78.61%
# predicted object person: 78.25%
# predicted object truck: 76.86%
# predicted object person: 75.94%
# predicted object car: 68.76%
# predicted object person: 68.16%
# predicted object car: 67.58%
# predicted object person: 54.15%
# predicted object truck: 53.54%
# predicted object trafficlight: 53.42%
# predicted object trafficlight: 52.10%
# predicted object trafficlight: 50.15%
# predicted object truck: 96.40%
# predicted object car: 91.89%
# predicted object person: 87.36%
# predicted object person: 87.29%
# predicted object person: 85.27%
# predicted object car: 84.85%
# predicted object car: 83.30%
# predicted object car: 79.35%
# predicted object person: 79.00%
# predicted object person: 78.49%
# predicted object person: 75.80%
# predicted object truck: 74.85%
# predicted object car: 71.77%
# predicted object person: 68.11%
# predicted object car: 67.43%
# predicted object truck: 54.46%
# predicted object person: 53.76%
# predicted object trafficlight: 53.59%
# predicted object trafficlight: 52.45%
# predicted object trafficlight: 50.14%
# predicted object truck: 96.02%
# predicted object car: 93.88%
# predicted object person: 87.38%
# predicted object person: 86.24%
# predicted object person: 84.71%
# predicted object car: 83.26%
# predicted object car: 81.69%
# predicted object car: 79.86%
# predicted object car: 78.60%
# predicted object person: 76.50%
# predicted object person: 76.45%
# predicted object truck: 74.18%
# predicted object person: 73.36%
# predicted object car: 70.57%
# predicted object person: 70.33%
# predicted object trafficlight: 56.79%
# predicted object trafficlight: 53.81%
# predicted object truck: 96.29%
# predicted object car: 92.48%
# predicted object person: 86.02%
# predicted object truck: 85.61%
# predicted object person: 84.45%
# predicted object car: 84.12%
# predicted object car: 83.85%
# predicted object person: 76.13%
# predicted object car: 74.64%
# predicted object person: 74.34%
# predicted object person: 73.63%
# predicted object person: 72.53%
# predicted object car: 69.36%
# predicted object person: 68.63%
# predicted object car: 68.06%
# predicted object trafficlight: 62.66%
# predicted object person: 55.98%
# predicted object trafficlight: 54.07%
# predicted object truck: 50.82%
# predicted object car: 50.56%
# predicted object truck: 95.92%
# predicted object car: 93.84%
# predicted object person: 88.47%
# predicted object person: 85.81%
# predicted object car: 84.48%
# predicted object car: 83.94%
# predicted object car: 77.53%
# predicted object person: 76.58%
# predicted object person: 75.86%
# predicted object person: 75.73%
# predicted object truck: 74.73%
# predicted object person: 72.50%
# predicted object car: 69.68%
# predicted object person: 68.78%
# predicted object trafficlight: 58.52%
# predicted object person: 57.34%
# predicted object trafficlight: 56.72%
# predicted object car: 52.23%
# predicted object person: 51.00%
# predicted object truck: 96.20%
# predicted object car: 93.99%
# predicted object person: 91.13%
# predicted object truck: 87.90%
# predicted object car: 84.85%
# predicted object car: 83.99%
# predicted object person: 80.82%
# predicted object person: 74.63%
# predicted object person: 74.10%
# predicted object car: 72.38%
# predicted object car: 72.27%
# predicted object car: 72.07%
# predicted object person: 67.92%
# predicted object person: 66.52%
# predicted object trafficlight: 58.91%
# predicted object trafficlight: 56.66%
# predicted object person: 55.10%
# predicted object person: 54.60%
# predicted object person: 52.69%
# predicted object truck: 96.23%
# predicted object car: 94.68%
# predicted object person: 93.41%
# predicted object truck: 90.35%
# predicted object person: 86.16%
# predicted object car: 85.64%
# predicted object car: 85.62%
# predicted object person: 79.56%
# predicted object person: 72.59%
# predicted object person: 71.41%
# predicted object car: 69.73%
# predicted object car: 69.67%
# predicted object person: 68.93%
# predicted object person: 64.56%
# predicted object person: 63.17%
# predicted object trafficlight: 61.08%
# predicted object trafficlight: 57.49%
# predicted object car: 52.71%
# predicted object truck: 96.15%
# predicted object car: 94.49%
# predicted object person: 93.64%
# predicted object truck: 90.01%
# predicted object person: 86.48%
# predicted object car: 85.22%
# predicted object car: 84.44%
# predicted object person: 79.69%
# predicted object person: 72.39%
# predicted object car: 70.59%
# predicted object person: 70.24%
# predicted object car: 66.27%
# predicted object person: 63.15%
# predicted object person: 62.67%
# predicted object trafficlight: 61.70%
# predicted object person: 60.78%
# predicted object trafficlight: 57.89%
# predicted object car: 51.29%
# predicted object truck: 95.56%
# predicted object car: 94.37%
# predicted object car: 83.83%
# predicted object person: 83.66%
# predicted object person: 83.26%
# predicted object car: 82.47%
# predicted object person: 82.32%
# predicted object car: 73.96%
# predicted object truck: 73.76%
# predicted object person: 68.18%
# predicted object car: 65.68%
# predicted object trafficlight: 62.87%
# predicted object trafficlight: 61.69%
# predicted object car: 61.49%
# predicted object person: 58.75%
# predicted object person: 58.71%
# predicted object person: 58.69%
# predicted object truck: 94.48%
# predicted object car: 94.05%
# predicted object person: 86.77%
# predicted object person: 84.78%
# predicted object car: 81.10%
# predicted object car: 80.50%
# predicted object truck: 78.86%
# predicted object car: 76.22%
# predicted object person: 74.28%
# predicted object car: 68.44%
# predicted object person: 63.76%
# predicted object car: 63.16%
# predicted object person: 62.99%
# predicted object trafficlight: 61.32%
# predicted object trafficlight: 60.39%
# predicted object person: 56.85%
# predicted object person: 56.10%
# predicted object person: 54.78%
# predicted object car: 95.13%
# predicted object truck: 94.42%
# predicted object truck: 87.73%
# predicted object person: 84.47%
# predicted object car: 83.73%
# predicted object car: 80.69%
# predicted object person: 79.23%
# predicted object car: 78.28%
# predicted object person: 76.44%
# predicted object person: 73.74%
# predicted object car: 68.22%
# predicted object person: 62.62%
# predicted object trafficlight: 61.55%
# predicted object trafficlight: 60.54%
# predicted object person: 59.69%
# predicted object person: 55.38%
# predicted object person: 51.13%
# predicted object car: 95.97%
# predicted object truck: 94.18%
# predicted object person: 84.72%
# predicted object car: 84.14%
# predicted object car: 80.79%
# predicted object car: 78.73%
# predicted object truck: 78.38%
# predicted object person: 76.86%
# predicted object car: 75.42%
# predicted object person: 73.97%
# predicted object car: 71.96%
# predicted object person: 69.78%
# predicted object person: 62.61%
# predicted object trafficlight: 61.61%
# predicted object trafficlight: 60.62%
# predicted object person: 59.57%
# predicted object person: 55.47%
# predicted object person: 54.27%
# predicted object person: 52.46%
# predicted object person: 50.41%
# predicted object car: 95.62%
# predicted object truck: 94.65%
# predicted object person: 84.87%
# predicted object car: 84.03%
# predicted object car: 79.56%
# predicted object person: 78.62%
# predicted object car: 78.37%
# predicted object car: 77.98%
# predicted object person: 76.50%
# predicted object person: 71.97%
# predicted object person: 70.18%
# predicted object car: 69.30%
# predicted object person: 64.44%
# predicted object trafficlight: 61.82%
# predicted object person: 59.64%
# predicted object person: 57.72%
# predicted object trafficlight: 57.07%
# predicted object car: 57.03%
# predicted object person: 55.99%
# predicted object person: 51.00%
# predicted object car: 95.71%
# predicted object truck: 94.45%
# predicted object person: 84.89%
# predicted object car: 84.53%
# predicted object car: 78.55%
# predicted object car: 78.43%
# predicted object car: 78.42%
# predicted object person: 78.13%
# predicted object person: 76.98%
# predicted object person: 71.57%
# predicted object person: 70.11%
# predicted object car: 69.71%
# predicted object person: 64.16%
# predicted object trafficlight: 61.66%
# predicted object person: 59.58%
# predicted object car: 56.95%
# predicted object trafficlight: 56.03%
# predicted object person: 55.80%
# predicted object person: 55.40%
# predicted object person: 50.82%
# predicted object car: 95.74%
# predicted object truck: 94.46%
# predicted object person: 84.89%
# predicted object car: 84.54%
# predicted object car: 78.53%
# predicted object car: 78.45%
# predicted object car: 78.43%
# predicted object person: 78.12%
# predicted object person: 76.97%
# predicted object person: 71.21%
# predicted object person: 70.10%
# predicted object car: 69.74%
# predicted object person: 64.14%
# predicted object trafficlight: 61.66%
# predicted object person: 59.40%
# predicted object car: 56.93%
# predicted object trafficlight: 56.04%
# predicted object person: 55.79%
# predicted object person: 55.38%
# predicted object person: 50.81%
# predicted object car: 96.15%
# predicted object truck: 94.44%
# predicted object person: 86.92%
# predicted object car: 84.93%
# predicted object car: 84.89%
# predicted object person: 82.01%
# predicted object truck: 78.86%
# predicted object person: 77.74%
# predicted object person: 73.80%
# predicted object car: 72.53%
# predicted object car: 72.50%
# predicted object person: 71.84%
# predicted object car: 71.44%
# predicted object person: 66.29%
# predicted object person: 65.16%
# predicted object trafficlight: 62.49%
# predicted object person: 61.19%
# predicted object person: 57.62%
# predicted object trafficlight: 54.82%
# predicted object person: 51.73%
# predicted object car: 95.70%
# predicted object truck: 95.34%
# predicted object person: 88.81%
# predicted object car: 88.51%
# predicted object person: 87.51%
# predicted object car: 85.18%
# predicted object truck: 80.26%
# predicted object person: 75.64%
# predicted object person: 75.64%
# predicted object car: 75.48%
# predicted object car: 73.56%
# predicted object car: 70.63%
# predicted object person: 68.20%
# predicted object person: 66.78%
# predicted object person: 66.59%
# predicted object trafficlight: 64.38%
# predicted object trafficlight: 62.40%
# predicted object person: 61.61%
# predicted object person: 60.10%
# predicted object person: 55.40%
# predicted object truck: 50.64%
# predicted object truck: 94.75%
# predicted object car: 94.04%
# predicted object person: 88.77%
# predicted object person: 88.28%
# predicted object car: 86.92%
# predicted object person: 86.25%
# predicted object car: 85.95%
# predicted object person: 80.72%
# predicted object person: 75.72%
# predicted object car: 75.71%
# predicted object person: 75.02%
# predicted object person: 73.19%
# predicted object car: 73.02%
# predicted object car: 72.80%
# predicted object person: 68.88%
# predicted object trafficlight: 61.18%
# predicted object person: 59.58%
# predicted object person: 58.45%
# predicted object trafficlight: 57.09%
# predicted object person: 57.05%
# predicted object person: 51.32%
# predicted object truck: 94.40%
# predicted object car: 92.62%
# predicted object car: 88.52%
# predicted object person: 88.47%
# predicted object car: 86.65%
# predicted object person: 85.80%
# predicted object person: 78.22%
# predicted object person: 77.43%
# predicted object car: 76.26%
# predicted object person: 75.85%
# predicted object person: 74.72%
# predicted object car: 74.49%
# predicted object person: 74.34%
# predicted object person: 71.54%
# predicted object car: 68.04%
# predicted object trafficlight: 67.27%
# predicted object person: 64.42%
# predicted object person: 59.89%
# predicted object trafficlight: 58.76%
# predicted object person: 55.55%
# predicted object person: 53.30%
# predicted object person: 51.34%
# predicted object car: 94.54%
# predicted object truck: 94.37%
# predicted object person: 91.12%
# predicted object car: 89.05%
# predicted object car: 86.45%
# predicted object person: 84.28%
# predicted object car: 80.24%
# predicted object person: 79.38%
# predicted object person: 77.58%
# predicted object person: 77.31%
# predicted object car: 76.49%
# predicted object person: 72.36%
# predicted object car: 70.48%
# predicted object person: 70.23%
# predicted object trafficlight: 69.05%
# predicted object person: 64.62%
# predicted object person: 62.73%
# predicted object person: 61.28%
# predicted object trafficlight: 58.47%
# predicted object person: 54.28%
# predicted object car: 50.42%
# predicted object truck: 94.18%
# predicted object car: 93.79%
# predicted object person: 91.41%
# predicted object car: 88.67%
# predicted object car: 87.22%
# predicted object person: 85.05%
# predicted object car: 79.63%
# predicted object person: 78.73%
# predicted object person: 77.32%
# predicted object car: 76.58%
# predicted object person: 76.39%
# predicted object person: 71.29%
# predicted object person: 70.47%
# predicted object trafficlight: 70.46%
# predicted object car: 70.35%
# predicted object person: 64.55%
# predicted object person: 60.77%
# predicted object person: 58.89%
# predicted object trafficlight: 57.59%
# predicted object person: 54.97%
# predicted object car: 51.04%
# predicted object trafficlight: 51.02%
# predicted object car: 94.35%
# predicted object truck: 93.65%
# predicted object car: 89.44%
# predicted object person: 87.63%
# predicted object person: 85.69%
# predicted object car: 82.18%
# predicted object car: 81.42%
# predicted object person: 80.21%
# predicted object person: 78.43%
# predicted object person: 76.65%
# predicted object car: 73.85%
# predicted object car: 71.26%
# predicted object trafficlight: 70.75%
# predicted object person: 69.36%
# predicted object person: 68.71%
# predicted object person: 64.59%
# predicted object person: 58.85%
# predicted object trafficlight: 57.99%
# predicted object person: 56.57%
# predicted object person: 54.20%
# predicted object trafficlight: 51.39%
# predicted object truck: 93.79%
# predicted object car: 93.58%
# predicted object car: 90.36%
# predicted object person: 85.66%
# predicted object car: 84.01%
# predicted object person: 80.92%
# predicted object person: 79.38%
# predicted object person: 75.57%
# predicted object person: 73.67%
# predicted object car: 73.67%
# predicted object car: 71.42%
# predicted object trafficlight: 70.60%
# predicted object person: 69.85%
# predicted object car: 69.48%
# predicted object person: 65.66%
# predicted object person: 60.70%
# predicted object trafficlight: 59.36%
# predicted object person: 57.60%
# predicted object person: 55.75%
# predicted object person: 55.40%
# predicted object person: 53.56%
# predicted object trafficlight: 51.92%
# predicted object truck: 51.04%
# predicted object truck: 94.94%
# predicted object car: 93.82%
# predicted object car: 90.54%
# predicted object person: 86.53%
# predicted object car: 83.86%
# predicted object person: 81.40%
# predicted object person: 81.00%
# predicted object person: 79.92%
# predicted object person: 79.58%
# predicted object car: 75.24%
# predicted object trafficlight: 73.22%
# predicted object person: 70.97%
# predicted object person: 67.79%
# predicted object person: 66.39%
# predicted object car: 62.04%
# predicted object car: 61.64%
# predicted object trafficlight: 61.02%
# predicted object truck: 57.74%
# predicted object person: 56.62%
# predicted object trafficlight: 50.91%
# predicted object truck: 94.92%
# predicted object car: 91.08%
# predicted object car: 89.41%
# predicted object person: 86.82%
# predicted object person: 86.00%
# predicted object car: 82.58%
# predicted object person: 79.59%
# predicted object person: 79.00%
# predicted object person: 78.54%
# predicted object car: 77.28%
# predicted object person: 73.01%
# predicted object trafficlight: 72.92%
# predicted object person: 70.79%
# predicted object person: 69.63%
# predicted object person: 65.84%
# predicted object trafficlight: 65.74%
# predicted object car: 62.06%
# predicted object car: 57.55%
# predicted object truck: 52.05%
# predicted object truck: 95.00%
# predicted object car: 93.64%
# predicted object person: 91.35%
# predicted object car: 89.06%
# predicted object person: 86.10%
# predicted object person: 86.10%
# predicted object person: 81.32%
# predicted object person: 80.70%
# predicted object person: 80.33%
# predicted object car: 78.26%
# predicted object person: 74.95%
# predicted object car: 74.56%
# predicted object trafficlight: 73.16%
# predicted object person: 71.68%
# predicted object person: 69.64%
# predicted object trafficlight: 63.17%
# predicted object car: 60.55%
# predicted object truck: 56.79%
# predicted object car: 50.61%
# predicted object truck: 95.15%
# predicted object car: 93.01%
# predicted object person: 91.39%
# predicted object car: 89.00%
# predicted object person: 85.93%
# predicted object person: 85.86%
# predicted object person: 80.14%
# predicted object person: 79.81%
# predicted object person: 78.36%
# predicted object car: 77.65%
# predicted object car: 75.79%
# predicted object person: 73.90%
# predicted object trafficlight: 73.09%
# predicted object person: 71.09%
# predicted object person: 67.18%
# predicted object trafficlight: 63.75%
# predicted object car: 60.89%
# predicted object truck: 57.90%
# predicted object truck: 95.79%
# predicted object person: 94.25%
# predicted object car: 93.09%
# predicted object car: 89.26%
# predicted object person: 85.98%
# predicted object person: 81.96%
# predicted object person: 79.82%
# predicted object person: 79.56%
# predicted object car: 78.89%
# predicted object car: 74.69%
# predicted object person: 73.94%
# predicted object trafficlight: 73.36%
# predicted object person: 70.54%
# predicted object person: 68.72%
# predicted object car: 66.00%
# predicted object trafficlight: 63.51%
# predicted object truck: 60.42%
# predicted object person: 60.20%
# predicted object truck: 95.31%
# predicted object person: 92.73%
# predicted object car: 90.65%
# predicted object car: 89.66%
# predicted object person: 86.32%
# predicted object person: 83.91%
# predicted object person: 82.52%
# predicted object person: 81.86%
# predicted object car: 80.85%
# predicted object person: 75.33%
# predicted object car: 74.46%
# predicted object person: 73.81%
# predicted object trafficlight: 71.84%
# predicted object person: 70.05%
# predicted object trafficlight: 63.18%
# predicted object car: 63.05%
# predicted object car: 61.23%
# predicted object person: 50.44%
# predicted object truck: 95.25%
# predicted object person: 91.26%
# predicted object car: 89.48%
# predicted object person: 84.26%
# predicted object car: 84.18%
# predicted object person: 83.72%
# predicted object person: 83.23%
# predicted object person: 82.82%
# predicted object car: 80.23%
# predicted object person: 76.50%
# predicted object person: 75.51%
# predicted object car: 74.98%
# predicted object person: 73.80%
# predicted object trafficlight: 69.30%
# predicted object person: 65.34%
# predicted object trafficlight: 62.71%
# predicted object car: 60.93%
# predicted object car: 57.80%
# predicted object trafficlight: 52.61%
# predicted object truck: 94.94%
# predicted object person: 91.80%
# predicted object car: 89.24%
# predicted object person: 85.69%
# predicted object person: 85.68%
# predicted object car: 83.54%
# predicted object person: 81.90%
# predicted object car: 79.65%
# predicted object person: 77.08%
# predicted object person: 75.40%
# predicted object person: 74.36%
# predicted object person: 70.25%
# predicted object car: 67.27%
# predicted object person: 66.90%
# predicted object trafficlight: 65.88%
# predicted object car: 65.84%
# predicted object truck: 60.33%
# predicted object trafficlight: 56.43%
# predicted object trafficlight: 54.63%
# predicted object truck: 95.29%
# predicted object car: 89.28%
# predicted object person: 88.58%
# predicted object person: 84.76%
# predicted object person: 82.32%
# predicted object car: 81.38%
# predicted object person: 81.02%
# predicted object car: 79.36%
# predicted object person: 78.44%
# predicted object person: 75.40%
# predicted object person: 71.31%
# predicted object person: 68.55%
# predicted object trafficlight: 65.59%
# predicted object person: 65.12%
# predicted object car: 64.56%
# predicted object truck: 64.49%
# predicted object trafficlight: 56.57%
# predicted object trafficlight: 53.46%
# predicted object truck: 95.17%
# predicted object car: 89.01%
# predicted object person: 88.45%
# predicted object person: 84.61%
# predicted object car: 84.05%
# predicted object person: 82.22%
# predicted object person: 81.22%
# predicted object car: 79.80%
# predicted object person: 77.61%
# predicted object person: 73.79%
# predicted object person: 72.15%
# predicted object person: 68.37%
# predicted object person: 65.60%
# predicted object trafficlight: 65.31%
# predicted object truck: 65.14%
# predicted object car: 64.45%
# predicted object trafficlight: 55.70%
# predicted object trafficlight: 53.42%
